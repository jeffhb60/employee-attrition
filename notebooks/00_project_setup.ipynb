# %% [markdown]
# # 00  — Project Setup
# This notebook verifies the project environment and shared configuration.
# Reusable constants can be found in `src/config.py`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.config import (RANDOM_STATE, TARGET, ID_COLUMN, TRAIN_RAW_PATH, TEST_RAW_PATH, PROCESSED_DATA_DIR, MODELS_DIR, RESULTS_DIR, FIGURES_DIR)

print('Project root:', PROJECT_ROOT)
print('Random state:', RANDOM_STATE)
print('Target:', TARGET)
# Out:
# Project root: C:\Users\jeffh\PycharmProjects\employee-attrition
# Random state: 42
# Target: Attrition

# %%
import pandas as pd
import numpy as np
import sklearn

print('pandas:', pd.__version__)
print('numpy:', np.__version__)
print('scikit-learn:', sklearn.__version__)
# Out:
# pandas: 3.0.5
# numpy: 2.4.6
# scikit-learn: 1.9.0

# %%
from IPython.display import display

train = pd.read_csv(TRAIN_RAW_PATH)
# test = pd.read_csv(TEST_RAW_PATH)

print('Train shape:', train.shape)
# print('Test shape:', test.shape)
display(train.head())
# Out:
# Train shape: (1058, 35)
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %%
required_dirs = [PROCESSED_DATA_DIR, MODELS_DIR, RESULTS_DIR, FIGURES_DIR]
for directory in required_dirs:
    print(f'{directory.name:>12}:', 'OK' if directory.exists() else 'MISSING')
# Out:
#    processed: OK
#       models: OK
#      results: OK
#      figures: OK
