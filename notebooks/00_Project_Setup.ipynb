# %% [markdown]
# # 00: Project Setup
# This notebook verifies the project environment and shared configuration.
# Reusable constants can be found in `src/config.py`.

# %%
libraries = {}

# %%
from src.config import (RANDOM_STATE, TARGET, TRAIN_RAW_PATH, PROCESSED_DATA_DIR, MODELS_DIR, RESULTS_DIR,RAW_DATA_DIR, FIGURES_DIR, PROJECT_ROOT)
import os

try:
    import dotenv
    from dotenv import load_dotenv, version
    libraries['python-dotenv'] = dotenv.version.__version__

except ImportError:
    # !pip install python-dotenv==1.2.3
    import dotenv
    from dotenv import load_dotenv, version
    libraries['python-dotenv'] = dotenv.version.__version__

try:
    import IPython
    from IPython.display import display
    libraries['IPython'] = IPython.__version__
except ImportError:
    # !pip install IPython==9.16.1
    import IPython
    from IPython.display import display
    libraries['IPython'] = IPython.__version__

try:
    import ipywidgets as widgets
    libraries['ipywidgets'] = widgets.__version__
except ImportError:
    # !pip install ipywidgets==8.1.9
    import ipywidgets as widgets
    libraries['ipywidgets'] = widgets.__version__

try:
    import kagglehub
    libraries['kagglehub'] = kagglehub.__version__
except ImportError:
    # !pip install kagglehub==1.0.2
    import kagglehub
    libraries['kagglehub'] = kagglehub.__version__

try:
    import lightgbm as lgb
    libraries['lightgbm'] = lgb.__version__
except ImportError:
    # !pip install lightgbm==4.7.0
    import lightgbm as lgb
    libraries['lightgbm'] = lgb.__version__

try:
    import numpy as np
    libraries['numpy'] = np.__version__
except ImportError:
    # !pip install numpy==2.4.6
    import numpy as np
    libraries['numpy'] = np.__version__

try:
    import pandas as pd
    libraries['pandas'] = pd.__version__
except ImportError:
    # !pip install pandas==3.0.5
    import pandas as pd
    libraries['pandas'] = pd.__version__

try:
    import sklearn
    libraries['scikit-learn'] = sklearn.__version__
except ImportError:
    # !pip install scikit-learn==1.9.0
    import sklearn
    libraries['scikit-learn'] = sklearn.__version__

try:
    import xgboost as xgb
    libraries['xgboost'] = xgb.__version__
except ImportError:
    # !pip install xgboost==3.2.0
    import xgboost as xgb
    libraries['xgboost'] = xgb.__version__

# %%
for key in libraries:
    print(f"{key}=={libraries[key]}")
# Out:
# python-dotenv==1.2.3
# IPython==9.16.1
# ipywidgets==8.1.9
# kagglehub==1.0.2
# lightgbm==4.7.0
# numpy==2.4.6
# pandas==3.0.5
# sklearn==1.9.0
# xgboost==3.2.0

# %%
print('Project root:', PROJECT_ROOT)
print('Random state:', RANDOM_STATE)
print('Target:', TARGET)
# Out:
# Project root: C:\Users\jeffh\PycharmProjects\employee-attrition
# Random state: 42
# Target: Attrition

# %%
load_dotenv()

username = os.environ.get('KAGGLE_USERNAME')
api_key = os.environ.get('KAGGLE_API_TOKEN')

if (RAW_DATA_DIR / 'train.csv').exists():
    print("Path to dataset files:", RAW_DATA_DIR / 'train.csv')
else:
    path = kagglehub.dataset_download(
        "rohitsahoo/employee",
        output_dir=RAW_DATA_DIR, force_download=True
    )

print("Path to dataset files:", RAW_DATA_DIR )
# Out:
# Path to dataset files: C:\Users\jeffh\PycharmProjects\employee-attrition\data\raw\train.csv
# Path to dataset files: C:\Users\jeffh\PycharmProjects\employee-attrition\data\raw

# %%
train = pd.read_csv(TRAIN_RAW_PATH)
# test = pd.read_csv(TEST_RAW_PATH)

print('Train shape:', train.shape)
display(train.head())
# Out:
# Train shape: (1058, 35)
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %%
required_dirs = [PROCESSED_DATA_DIR, MODELS_DIR, RESULTS_DIR, FIGURES_DIR]
for directory in required_dirs:
    print(f'{directory.name:>12}:', 'OK' if directory.exists() else 'MISSING')
# Out:
#    processed: OK
#       models: OK
#      results: OK
#      figures: OK
