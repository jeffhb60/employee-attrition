# %% [markdown]
# # 00: Project Setup
# This notebook verifies the project environment and shared configuration.
# Reusable constants can be found in `src/config.py`.

# %%
from src.config import (
    RANDOM_STATE,
    TARGET,
    TRAIN_RAW_PATH,
    PROCESSED_DATA_DIR,
    MODELS_DIR,
    RESULTS_DIR,
    RAW_DATA_DIR,
    FIGURES_DIR,
    PROJECT_ROOT,
)

import os

import numpy as np
import pandas as pd
import sklearn
import xgboost as xgb
import lightgbm as lgb
import kagglehub
import ipywidgets as widgets
import IPython
import matplotlib

from IPython.display import display

# %%
libraries = {
    "IPython": IPython.__version__,
    "ipywidgets": widgets.__version__,
    "kagglehub": kagglehub.__version__,
    "lightgbm": lgb.__version__,
    "numpy": np.__version__,
    "pandas": pd.__version__,
    "scikit-learn": sklearn.__version__,
    "xgboost": xgb.__version__,
    "matplotlib": matplotlib.__version__,
}

pd.DataFrame(
    libraries.items(),
    columns=["Library", "Version"],
)
# Out:
#         Library Version
# 0       IPython  9.16.1
# 1    ipywidgets   8.1.9
# 2     kagglehub   1.0.2
# 3      lightgbm   4.7.0
# 4         numpy   2.4.6
# 5        pandas   3.0.5
# 6  scikit-learn   1.9.0
# 7       xgboost   3.2.0
# 8    matplotlib  3.11.1

# %%
print('Project root:', PROJECT_ROOT)
print('Random state:', RANDOM_STATE)
print('Target:', TARGET)
# Out:
# Project root: C:\Users\jeffh\PycharmProjects\employee-attrition
# Random state: 42
# Target: Attrition

# %%
if (RAW_DATA_DIR / 'train.csv').exists():
    print("Path to dataset files:", RAW_DATA_DIR / 'train.csv')
else:
    path = kagglehub.dataset_download(
        "rohitsahoo/employee",
        output_dir=RAW_DATA_DIR, force_download=True
    )

print("Path to dataset files:", RAW_DATA_DIR )
# Out:
# ...
# 100%|██████████| 50.9k/50.9k [00:00<00:00, 2.76MB/s]
# Extracting files...
# Path to dataset files: C:\Users\jeffh\PycharmProjects\employee-attrition\data\raw

# %%
train = pd.read_csv(TRAIN_RAW_PATH)
# test = pd.read_csv(TEST_RAW_PATH)

print('Train shape:', train.shape)
display(train.head())
# Out:
# Train shape: (1058, 35)
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %%
required_dirs = [RAW_DATA_DIR, PROCESSED_DATA_DIR, MODELS_DIR, RESULTS_DIR, FIGURES_DIR]
for directory in required_dirs:
    print(f'{directory.name:>12}:', 'OK' if directory.exists() else 'MISSING')
# Out:
#          raw: OK
#    processed: OK
#       models: OK
#      results: OK
#      figures: OK
